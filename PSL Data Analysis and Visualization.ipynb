# %% [markdown]
# # PSL Data Analysis & Visualization

# %% [markdown]
# Dataset: https://www.kaggle.com/datasets/muhammadkhalid/pakistan-super-league-datasets

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Preperation and Cleaning

# %% [markdown]
# ### Reading Data using Pandas

# %% [markdown]
# #### Timeline Data

# %%
most_wins=pd.read_csv("PSL Dataset\Timeline data\Most match wins in PSL since 2016.csv")
most_wins
# Out:
#            Team Name                                          Image URL  \
# 0  Quetta Gladiators  https://upload.wikimedia.org/wikipedia/en/d/d2...
# 1      Karachi Kings  https://upload.wikimedia.org/wikipedia/en/thum...
# 2     Peshawar Zalmi  https://upload.wikimedia.org/wikipedia/en/thum...
# 3   Islamabad United  https://upload.wikimedia.org/wikipedia/en/9/92...
# 4   Lahore Qalandars  https://upload.wikimedia.org/wikipedia/en/6/63...
# 5     Multan Sultans  https://upload.wikimedia.org/wikipedia/en/thum...
#
#    Match # 1  Match # 2  Match # 3  Match # 4  Match # 5  Match # 6  \
# 0          1          1          1          2          2          2
# 1          0          1          1          1          1          1
# 2          0          0          1          1          2          2
# 3          0          0          0          0          0          1
# 4          0          0          0          0          0          0
# ...

# %%
most_wins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Columns: 146 entries, Team Name to Match # 144
# dtypes: int64(144), object(2)
# memory usage: 7.0+ KB

# %%
most_wins.shape
# Out:
# (6, 146)

# %%
most_wins.describe
# Out:
# <bound method NDFrame.describe of            Team Name                                          Image URL  \
# 0  Quetta Gladiators  https://upload.wikimedia.org/wikipedia/en/d/d2...
# 1      Karachi Kings  https://upload.wikimedia.org/wikipedia/en/thum...
# 2     Peshawar Zalmi  https://upload.wikimedia.org/wikipedia/en/thum...
# 3   Islamabad United  https://upload.wikimedia.org/wikipedia/en/9/92...
# 4   Lahore Qalandars  https://upload.wikimedia.org/wikipedia/en/6/63...
# 5     Multan Sultans  https://upload.wikimedia.org/wikipedia/en/thum...
#
#    Match # 1  Match # 2  Match # 3  Match # 4  Match # 5  Match # 6  \
# 0          1          1          1          2          2          2
# 1          0          1          1          1          1          1
# 2          0          0          1          1          2          2
# 3          0          0          0          0          0          1
# 4          0          0          0          0          0          0
# ...

# %%
most_wins.drop(columns=['Image URL'],inplace=True)

# %%
most_wins.columns
# Out:
# Index(['Team Name', 'Match # 1', 'Match # 2', 'Match # 3', 'Match # 4',
#        'Match # 5', 'Match # 6', 'Match # 7', 'Match # 8', 'Match # 9',
#        ...
#        'Match # 135', 'Match # 136', 'Match # 137', 'Match # 138',
#        'Match # 139', 'Match # 140', 'Match # 141', 'Match # 142',
#        'Match # 143', 'Match # 144'],
#       dtype='object', length=145)

# %%
most_wins
# Out:
#            Team Name  Match # 1  Match # 2  Match # 3  Match # 4  Match # 5  \
# 0  Quetta Gladiators          1          1          1          2          2
# 1      Karachi Kings          0          1          1          1          1
# 2     Peshawar Zalmi          0          0          1          1          2
# 3   Islamabad United          0          0          0          0          0
# 4   Lahore Qalandars          0          0          0          0          0
# 5     Multan Sultans          0          0          0          0          0
#
#    Match # 6  Match # 7  Match # 8  Match # 9  ...  Match # 135  Match # 136  \
# 0          2          3          3          3  ...           28           28
# 1          1          1          1          1  ...           20           21
# 2          2          2          2          2  ...           31           31
# 3          1          1          1          2  ...           29           29
# ...

# %%
most_sixes=pd.read_csv("PSL Dataset\Timeline data\Most sixes by a player in PSL since 2016.csv")
most_sixes
# Out:
#              Player Name  PSL 2016 | Match # 1  PSL 2016 | Match # 2  \
# 0           Shane Watson                     0                     0
# 1          Sharjeel Khan                     1                     1
# 2              Umar Amin                     0                     0
# 3             Babar Azam                     0                     0
# 4           Sam Billings                     0                     0
# ..                   ...                   ...                   ...
# 225  Sherfane Rutherford                     0                     0
# 226        Waqas Maqsood                     0                     0
# 227       Faf du Plessis                     0                     0
# 228       Mohammad Imran                     0                     0
# 229        Saqib Mahmood                     0                     0
#
#      PSL 2016 | Match # 3  PSL 2016 | Match # 4  PSL 2016 | Match # 5  \
# ...

# %%
most_wickets=pd.read_csv("PSL Dataset\Timeline data\Most wickets taken by a player in PSL since 2016.csv")
most_wickets
# Out:
#         Player Name  PSL 2016 | Match # 1  PSL 2016 | Match # 2  \
# 0         Anwar Ali                     1                     1
# 1    Zulfiqar Babar                     1                     1
# 2     Mohammad Nabi                     0                     0
# 3          Umar Gul                     1                     1
# 4    Mohammad Nawaz                     4                     4
# ..              ...                   ...                   ...
# 158     Usman Qadir                     0                     0
# 159        Ali Khan                     0                     0
# 160       Adam Lyth                     0                     0
# 161   Saqib Mahmood                     0                     0
# 162  Mohammad Imran                     0                     0
#
#      PSL 2016 | Match # 3  PSL 2016 | Match # 4  PSL 2016 | Match # 5  \
# 0                       1                     3                     3
# ...

# %% [markdown]
# #### Team Records

# %%
highest_total=pd.read_csv("PSL Dataset\Team Records\Highest totals in PSL.csv")
highest_total
# Out:
#           Team  Score  Overs     RR  Inns    Opposition       Ground  \
# 0       United  238/3   20.0  11.90     1   v Qalandars      Karachi
# 1        Zalmi  214/5   20.0  10.70     1      v United      Karachi
# 2    Qalandars  209/5   20.0  10.45     1  v Gladiators       Lahore
# 3    Qalandars  204/4   20.0  10.20     2     v Sultans      Sharjah
# 4   Gladiators  203/8   20.0  10.15     2   v Qalandars  Dubai (DSC)
# 5        Zalmi  203/7   20.0  10.15     1       v Kings      Karachi
# 6   Gladiators  202/5   18.5  10.72     2   v Qalandars      Sharjah
# 7    Qalandars  201/2   20.0  10.05     1  v Gladiators  Dubai (DSC)
# 8        Kings  201/4   20.0  10.05     1       v Zalmi      Karachi
# 9    Qalandars  200/3   20.0  10.00     1  v Gladiators      Sharjah
# 10  Gladiators  200/7   20.0  10.00     1       v Zalmi      Sharjah
# 11     Sultans  200/6   20.0  10.00     1   v Qalandars      Sharjah
# 12       Zalmi  199/9   20.0   9.95     2  v Gladiators      Sharjah
# ...

# %%
highest_total.Ground.unique()
# Out:
# array(['Karachi', 'Lahore', 'Sharjah', 'Dubai (DSC)', 'Multan',
#        'Rawalpindi', 'Abu Dhabi'], dtype=object)

# %%
highest_total.Team.unique()
# Out:
# array(['United', 'Zalmi', 'Qalandars', 'Gladiators', 'Kings', 'Sultans'],
#       dtype=object)

# %%
highest_total.Team.replace({
    'United':'Islamabad United',  
    'Qalandars':'Lahore Qalandars', 
    'Zalmi':'Peshawar Zalmi', 
    'Gladiators':'Quetta Gladiators',
    'Kings':'Karachi Kings', 
    'Sultans':'Multan Sultans'}
, inplace=True)

highest_total.Opposition.replace({
    'v United':'Islamabad United',  
    'v Qalandars':'Lahore Qalandars', 
    'v Zalmi':'Peshawar Zalmi', 
    'v Gladiators':'Quetta Gladiators',
    'v Kings':'Karachi Kings', 
    'v Sultans':'Multan Sultans'}
, inplace=True)

# %%
highest_total
# Out:
#                  Team  Score  Overs     RR  Inns         Opposition  \
# 0    Islamabad United  238/3   20.0  11.90     1   Lahore Qalandars
# 1      Peshawar Zalmi  214/5   20.0  10.70     1   Islamabad United
# 2    Lahore Qalandars  209/5   20.0  10.45     1  Quetta Gladiators
# 3    Lahore Qalandars  204/4   20.0  10.20     2     Multan Sultans
# 4   Quetta Gladiators  203/8   20.0  10.15     2   Lahore Qalandars
# 5      Peshawar Zalmi  203/7   20.0  10.15     1      Karachi Kings
# 6   Quetta Gladiators  202/5   18.5  10.72     2   Lahore Qalandars
# 7    Lahore Qalandars  201/2   20.0  10.05     1  Quetta Gladiators
# 8       Karachi Kings  201/4   20.0  10.05     1     Peshawar Zalmi
# 9    Lahore Qalandars  200/3   20.0  10.00     1  Quetta Gladiators
# 10  Quetta Gladiators  200/7   20.0  10.00     1     Peshawar Zalmi
# 11     Multan Sultans  200/6   20.0  10.00     1   Lahore Qalandars
# 12     Peshawar Zalmi  199/9   20.0   9.95     2  Quetta Gladiators
# ...

# %%
summary=pd.read_csv("PSL Dataset\Team Records\Result summary of teams in PSL.csv")
summary
# Out:
#                 Team       Span  Match  Won  Lost  Tied  Tie+W  Tie+L  NR  \
# 0   Islamabad United  2016-2020     53   28    24     0      1      0   0
# 1      Karachi Kings  2016-2020     54   23    27     0      1      1   2
# 2   Lahore Qalandars  2016-2020     49   17    30     0      1      1   0
# 3     Multan Sultans  2018-2020     31   13    15     0      0      1   2
# 4     Peshawar Zalmi  2016-2020     57   31    25     0      0      0   1
# 5  Quetta Gladiators  2016-2020     52   30    21     0      0      0   1
#
#        %
# 0  53.77
# 1  46.15
# 2  36.73
# 3  46.55
# 4  55.35
# 5  58.82

# %%
del summary['Span']

# %%
summary
# Out:
#                 Team  Match  Won  Lost  Tied  Tie+W  Tie+L  NR      %
# 0   Islamabad United     53   28    24     0      1      0   0  53.77
# 1      Karachi Kings     54   23    27     0      1      1   2  46.15
# 2   Lahore Qalandars     49   17    30     0      1      1   0  36.73
# 3     Multan Sultans     31   13    15     0      0      1   2  46.55
# 4     Peshawar Zalmi     57   31    25     0      0      0   1  55.35
# 5  Quetta Gladiators     52   30    21     0      0      0   1  58.82

# %% [markdown]
# ### Check NaN Values

# %%
most_wins.isna().any()[lambda x: x]
# Out:
# Series([], dtype: bool)

# %%
most_sixes.isna().any()[lambda x: x]
# Out:
# Series([], dtype: bool)

# %%
most_wickets.isna().any()[lambda x: x]
# Out:
# Series([], dtype: bool)

# %%
highest_total.isna().any()[lambda x: x]
# Out:
# Series([], dtype: bool)

# %%
summary.isna().any()[lambda x: x]
# Out:
# Series([], dtype: bool)

# %% [markdown]
# ## Exploratory Analysis and Visualization

# %% [markdown]
# ### Most Wins by Teams

# %%
mw=most_wins.iloc[ : ,[0,-1]]
mw.rename(columns={'Match # 144':'Wins'}, inplace = True)
mw=mw.sort_values(by=['Wins'], ascending=False).reset_index()
mw.iloc[:,[1,-1]]   #else it will also includes prev indexes
# Out:
# C:\Users\Saba\AppData\Local\Temp\ipykernel_13444\3610845028.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mw.rename(columns={'Match # 144':'Wins'}, inplace = True)
#            Team Name  Wins
# 0     Peshawar Zalmi    31
# 1  Quetta Gladiators    29
# 2   Islamabad United    29
# 3      Karachi Kings    24
# 4   Lahore Qalandars    18
# 5     Multan Sultans    13

# %%
#plt.figaspect
#plt.figure(figsize=(20,10))
plt.figure()
plt.grid()
plt.title('Most Wins by Teams')
sns.barplot(x='Wins',y='Team Name',data=mw)
# Out:
# <AxesSubplot:title={'center':'Most Wins by Teams'}, xlabel='Wins', ylabel='Team Name'>

# %%
mwt=most_wins.transpose()   #for line plot
nh=mwt.iloc[0]
mwt=mwt[1:]
mwt.columns=nh

# %%
#plot=mwt.plot(figsize=(20, 10))
plot=mwt.plot()
plot.axes.get_xaxis().set_visible(False)
plot.grid()
plot.legend(loc=0, prop={'size': 8})
plot
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Most Sixes by Players

# %%
ms=most_sixes.iloc[ : ,[0,-1]]
ms.rename(columns={'PSL 2020 | Match # 34':'Sixes'}, inplace = True)
ms=ms.sort_values(by=['Sixes'], ascending=False).reset_index()

del ms['index']
ms
#ms.iloc[:,[1,-1]]
# Out:
# C:\Users\Saba\AppData\Local\Temp\ipykernel_13444\1240410512.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ms.rename(columns={'PSL 2020 | Match # 34':'Sixes'}, inplace = True)
#        Player Name  Sixes
# 0     Shane Watson     81
# 1     Kamran Akmal     77
# 2      Luke Ronchi     50
# 3         Asif Ali     50
# 4      Daren Sammy     44
# ..             ...    ...
# 225  Kamran Ghulam      0
# 226      Rahat Ali      0
# 227   Khalid Usman      0
# 228  Sabbir Rahman      0
# 229  Saqib Mahmood      0
#
# [230 rows x 2 columns]

# %% [markdown]
# #### Top 15 Players with most Sixes

# %%
tms=ms.head(15)
tms
# Out:
#         Player Name  Sixes
# 0      Shane Watson     81
# 1      Kamran Akmal     77
# 2       Luke Ronchi     50
# 3          Asif Ali     50
# 4       Daren Sammy     44
# 5    Kieron Pollard     44
# 6      Fakhar Zaman     42
# 7        Umar Akmal     42
# 8      Shoaib Malik     41
# 9      Colin Ingram     40
# 10  Mohammad Hafeez     37
# 11    Shahid Afridi     36
# 12    Sharjeel Khan     35
# 13    Rilee Rossouw     34
# 14  Cameron Delport     33

# %%
plt.figure()
plt.grid()
plt.title('Top 15 Players with most sixes')
sns.barplot(x='Sixes',y='Player Name',data=tms)
# Out:
# <AxesSubplot:title={'center':'Top 15 Players with most sixes'}, xlabel='Sixes', ylabel='Player Name'>

# %% [markdown]
# ### Most Wickets taken by a Player

# %%
mw=most_wickets.iloc[ : ,[0,-1]]
mw.rename(columns={'PSL 2020 | Match # 34':'Wickets'}, inplace = True)
mw=mw.sort_values(by=['Wickets'], ascending=False).reset_index()

del mw['index']
mw
# Out:
# C:\Users\Saba\AppData\Local\Temp\ipykernel_13444\2562800205.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mw.rename(columns={'PSL 2020 | Match # 34':'Wickets'}, inplace = True)
#         Player Name  Wickets
# 0        Wahab Riaz       76
# 1         Hasan Ali       59
# 2     Mohammad Amir       49
# 3    Mohammad Nawaz       49
# 4     Sohail Tanvir       48
# ..              ...      ...
# 158  Sohaib Maqsood        0
# 159        Nabi Gul        0
# 160      Saad Nasim        0
# 161      Bilal Asif        0
# 162    Colin Ingram        0
#
# [163 rows x 2 columns]

# %% [markdown]
# #### Top 15 Players with most Wickets

# %%
tmw=mw.head(15)
tmw
# Out:
#             Player Name  Wickets
# 0            Wahab Riaz       76
# 1             Hasan Ali       59
# 2         Mohammad Amir       49
# 3        Mohammad Nawaz       49
# 4         Sohail Tanvir       48
# 5         Faheem Ashraf       46
# 6         Shahid Afridi       42
# 7         Mohammad Sami       42
# 8           Sohail Khan       37
# 9           Shadab Khan       37
# 10       Usman Shinwari       35
# 11         Rumman Raees       34
# 12            Rahat Ali       34
# 13  Shaheen Shah Afridi       34
# 14   Mohammad Irfan Snr       33

# %%
plt.figure()
plt.grid()
plt.title('Top 15 Players with most wickets')
sns.barplot(x='Wickets',y='Player Name',data=tmw)
# Out:
# <AxesSubplot:title={'center':'Top 15 Players with most wickets'}, xlabel='Wickets', ylabel='Player Name'>

# %% [markdown]
# ### Player(s) in Top 20 for both Sixes & Wickets

# %%
tms['Player Name'].isin(tmw['Player Name']).value_counts()
# Out:
# False    14
# True      1
# Name: Player Name, dtype: int64

# %%
best=tms.loc[tms['Player Name'].isin(tmw['Player Name'])].reset_index()
best=best['Player Name']
best=best.to_string(index=False)

best
# Out:
# 'Shahid Afridi'

# %% [markdown]
# ### Matches Info for runs above 180

# %%
#Split Score
highest_total[['Runs','Out']]=highest_total.Score.str.split(pat='/',expand=True).astype('int')

# %%
highest_total
# Out:
#                  Team  Score  Overs     RR  Inns         Opposition  \
# 0    Islamabad United  238/3   20.0  11.90     1   Lahore Qalandars
# 1      Peshawar Zalmi  214/5   20.0  10.70     1   Islamabad United
# 2    Lahore Qalandars  209/5   20.0  10.45     1  Quetta Gladiators
# 3    Lahore Qalandars  204/4   20.0  10.20     2     Multan Sultans
# 4   Quetta Gladiators  203/8   20.0  10.15     2   Lahore Qalandars
# 5      Peshawar Zalmi  203/7   20.0  10.15     1      Karachi Kings
# 6   Quetta Gladiators  202/5   18.5  10.72     2   Lahore Qalandars
# 7    Lahore Qalandars  201/2   20.0  10.05     1  Quetta Gladiators
# 8       Karachi Kings  201/4   20.0  10.05     1     Peshawar Zalmi
# 9    Lahore Qalandars  200/3   20.0  10.00     1  Quetta Gladiators
# 10  Quetta Gladiators  200/7   20.0  10.00     1     Peshawar Zalmi
# 11     Multan Sultans  200/6   20.0  10.00     1   Lahore Qalandars
# 12     Peshawar Zalmi  199/9   20.0   9.95     2  Quetta Gladiators
# ...

# %%
plt.plot(highest_total.Runs)

# %% [markdown]
# #### Which Innings Players has the highest Out Rate?

# %%
ivo=highest_total.iloc[ : ,[4,-1]]

# %%
ivo.Inns.replace({
    1:'Batting',
    2:'Fielding'
},inplace=True)
ivo=ivo.groupby("Inns")
ivo=ivo.sum()

ivo
# Out:
# C:\Users\Saba\AppData\Local\Temp\ipykernel_13444\2901803124.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ivo.Inns.replace({
#           Out
# Inns
# Batting   180
# Fielding   80

# %% [markdown]
# #### Which innings have the most highest scores?

# %%
inn = highest_total.pivot_table(columns=['Inns'], aggfunc='size')
inn
# Out:
# Inns
# 1    36
# 2    14
# dtype: int64

# %% [markdown]
# #### Which venue hosted most of the matches?

# %%
highest_total.Ground.unique()
# Out:
# array(['Karachi', 'Lahore', 'Sharjah', 'Dubai (DSC)', 'Multan',
#        'Rawalpindi', 'Abu Dhabi'], dtype=object)

# %%
venue=highest_total.groupby('Ground')[['Match Date']].count()
venue=venue.sort_values('Match Date',ascending=False).reset_index()
venue.rename(columns={
    'Ground':'Venue',
    'Match Date' : 'Total'
},inplace=True)
venue
# Out:
#          Venue  Total
# 0      Sharjah     12
# 1  Dubai (DSC)     10
# 2      Karachi     10
# 3       Lahore     10
# 4   Rawalpindi      5
# 5       Multan      2
# 6    Abu Dhabi      1

# %%
labels=list(venue.Venue)

# %%
plt.pie(venue.Total, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x19781b9bd90>,
# ...
#  [Text(0.8018655028537539, 0.7530018030078657, 'Sharjah'),
#   Text(-0.5894094518681141, 0.9287607324001856, 'Dubai (DSC)'),
#   Text(-1.0654414787782402, -0.27355886989611017, 'Karachi'),
#   Text(-0.06906955709217558, -1.097829402176445, 'Lahore'),
#   Text(0.8475645860912688, -0.7011663657106895, 'Rawalpindi'),
#   Text(1.0654414851813472, -0.2735588449576531, 'Multan'),
#   Text(1.0978294029847897, -0.06906954424390042, 'Abu Dhabi')])

# %% [markdown]
# ## PSL Matches Summary

# %%
summary
# Out:
#                 Team  Match  Won  Lost  Tied  Tie+W  Tie+L  NR      %
# 0   Islamabad United     53   28    24     0      1      0   0  53.77
# 1      Karachi Kings     54   23    27     0      1      1   2  46.15
# 2   Lahore Qalandars     49   17    30     0      1      1   0  36.73
# 3     Multan Sultans     31   13    15     0      0      1   2  46.55
# 4     Peshawar Zalmi     57   31    25     0      0      0   1  55.35
# 5  Quetta Gladiators     52   30    21     0      0      0   1  58.82

# %%
plt.title("Wining vs Match Played w.r.t Teams")

plt.plot(summary.Match)
plt.plot(summary.Won)

plt.grid()
#plt.legend(loc=2)

# %% [markdown]
# ## Refrences:

# %% [markdown]
# https://jovian.ai/pratik2022000/ipl-data-analysis-and-visualization
#
# https://pandas.pydata.org/pandasdocs/version/0.23/generated/pandas.DataFrame.plot.html
#
# https://www.statology.org/pandas-select-column-by-index/
#
# https://datascience.stackexchange.com/questions/33053/how-do-i-compare-columns-in-different-data-frames
#
# https://sparkbyexamples.com/pandas/print-pandas-dataframe-without-index/#:~:text=2.-,Using%20DataFrame.,the%20DataFrame%20object%20to%20print.
#
# https://www.delftstack.com/howto/python-pandas/split-column-in-python-pandas/#:~:text=We%20can%20use%20the%20pandas,to%20the%20entire%20Dataframe%20column.
#
# https://www.youtube.com/watch?v=AYorFcI1MTU
#
# https://datatofish.com/count-duplicates-pandas/
